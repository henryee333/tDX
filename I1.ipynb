# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import style

# %%
im1 = pd.read_csv('IM1.csv', encoding='latin1')[1:27]
im1["Email Address"] = im1["Email Address"].apply(lambda str: str.lower())
im1.sort_values("Name")
# Out:
#         Timestamp                  Email Address                     Name  \
# 16   7/9/17 16:23       tiago.tadeu@berkeley.edu     Bezerra, Tiago Tadeu
# 4    7/11/17 0:18          dnlchang@berkeley.edu            Chang, Daniel
# 2   7/10/17 21:15  chenjingling2017@berkeley.edu   Chen, Jingling (Lynne)
# 14  7/10/17 22:47              x841010@gmail.com     Chen, Shih Chi (Tim)
# 19   7/11/17 7:54           tzujung@berkeley.edu           Chen, Tzu Jung
# 18  7/11/17 12:26            tyfeng@berkeley.edu                 Feng, Ty
# 17   7/11/17 3:00       trishagiron@berkeley.edu        Giron, Trisha Mae
# 7   7/12/17 21:02         guokaifei@berkeley.edu      Guo, Kaifei (Kevin)
# 8   7/10/17 15:40              1103896880@qq.com    Han, Kaiyang (Holmes)
# 5    7/11/17 0:32          imha0404@berkeley.edu             Haupt, Imani
# 23   7/9/17 17:28             7822684021@163.com                Hu, Yuxin
# 22  7/10/17 20:08      yuchenjiao95@berkeley.edu             Jiao, Yuchen
# 11  7/10/17 20:19            mkarch@berkeley.edu     Karchemsky, Mitchell
# 3    7/11/17 1:01         c.lee0504@berkeley.edu             Lee, Crystal
# 13   7/11/17 0:17         ruixeli93@berkeley.edu               Li, Ruixue
# 24  7/10/17 14:51        eileen1217@berkeley.edu              Liu, Zelan
# 26            NaN      sophialu0708@berkeley.edu                Lu, Sifan
# 12   7/11/17 0:19           rosemin@berkeley.edu                Min, Rose
# 10  7/10/17 19:57           mcreese@berkeley.edu           Reese, Michael
# 1   7/10/17 18:14       avidyasagar@berkeley.edu             Sagar, Anand
# 9    7/11/17 8:16      msanchez0406@berkeley.edu  Sanchez Sendiz, Martin
# 6   7/10/17 21:35           jakulik@berkeley.edu    Stamboltsian, Jackie
# 15   7/11/17 0:58         ttagliari@berkeley.edu         Tagliari, Thiago
# 25  7/10/17 11:59    charliewangzixuan@gmail.com  Wang, Zixuan (Charlie)
# 21   7/11/17 9:50         xiuyuanxi@berkeley.edu              Xiu, Yuanxi
# 20  7/10/17 12:15               v23515@gmail.com            Yen, Yen Tina
#
#    AEIOU AEIOU.1                                            AEIOU.2 POEMS  \
# 16    No      No  Because in my routine as Product Manager and B...    No
# 4     No      No  It does not take location based information in...    No
# 2    Yes     Yes  Because it can be heuristic and be a guideline...   Yes
# 14    No     Yes  It's a comprehensive method that can make sure...    No
# 19    No      No  AEIOU is a research method mostly focuses on c...    No
# 18    No      No  AEIOU is needed when simplifying large amounts...   Yes
# 17    No     Yes  It gives a good framework for organizing and i...    No
# 7     No     Yes  Observations are everywhere and of various kin...    No
# 8     No      No  The benefit of this method is not suitable for...   Yes
# 5     No      No  Don't use it may in the future but It is not f...    No
# 23   Yes      No  Because it seems much clearer to figure out wh...    No
# 22    No      No  The AEIOU is too precise and limited which is ...    No
# 11   Yes     Yes  I like that AEIOU focuses on a more holistic a...    No
# 3     No      No  I didn't chose this method because it's situat...    No
# 13    No      No  This method is not suitable for big picture ca...    No
# 24    No     Yes  AEIOU consists of 5 elements: activity, enviro...    No
# 26   NaN     NaN                                                NaN   NaN
# 12    No     Yes  Despite its limitations of not being able to c...    No
# 10    No     Yes  The selection of AEIOU is based on a desire to...    No
# 1     No     Yes         It is a useful way to organize information    No
# 9     No     Yes  This method would allow me to keep my observat...    No
# 6     No      No       I chose POSTA, a similar method, over AEIOU.    No
# 15    No      No  Because it limits you in some precise situatio...    No
# 25   Yes     Yes  AEIOU is a coding structure mnemonic used to o...    No
# 21   Yes     Yes  It concludes all main elements of a thing. It'...    No
# 20    No      No                               It takes a long time    No
#
#    POEMS.1                                            POEMS.2 POSTA  \
# 16      No  Because in my routine as Product Manager and B...    No
# 4      Yes  Seems to provide a fairly broad foundation for...    No
# 2       No    It has some simiarities with the methods AEIOU.   Yes
# 14      No              cant figure out what exactly it means    No
# 19     Yes  POEMS helps researcher to capture specific pie...    No
# 18      No  POEMS is needed when learning about new unfami...    No
# 17      No  It does not strike too much as something that ...    No
# 7      Yes  To organize observations, it is often better t...    No
# 8      Yes  After we get information, we need to analysis ...   Yes
# 5       No                      Not enough information on it.    No
# 23      No                 It seems much more mess than AEIOU    No
# 22      No      The gathered information may be too trivial.     No
# 11      No  I feel like i'll be using this in sort of a mi...    No
# 3       No  I did not choose this method because I prefer ...    No
# 13     Yes  This method can help researchers to understand...    No
# 24      No  This method also consists of 5 elements: peopl...    No
# 26     NaN                                                NaN   NaN
# 12      No  I did not choose it because I did not have eno...    No
# 10      No  I feel as if POEMS is a more general method, w...    No
# 1       No                         It did not seem worthwhile    No
# 9       No  The method is similar to AEIOU but categorizes...    No
# 6       No    I chose POSTA, a related method, over this one.    No
# 15      No  Because this method limits you in some precise...    No
# 25      No  POEMS framework family research should be done...    No
# 21      No  I think my thinking mode is more same as AEIOU...   Yes
# 20      No                 It needs great observation ability    No
#
#        ...     Usability Testing Usability Testing.1  \
# 16     ...                   Yes                  No
# 4      ...                    No                  No
# 2      ...                   Yes                 Yes
# 14     ...                    No                  No
# 19     ...                   Yes                 Yes
# 18     ...                   Yes                  No
# 17     ...                   Yes                  No
# 7      ...                   Yes                 Yes
# 8      ...                    No                  No
# 5      ...                    No                  No
# 23     ...                    No                  No
# 22     ...                    No                  No
# 11     ...                   Yes                  No
# 3      ...                    No                 Yes
# 13     ...                    No                  No
# 24     ...                   Yes                  No
# 26     ...                   NaN                 NaN
# 12     ...                   Yes                  No
# 10     ...                   Yes                  No
# 1      ...                    No                  No
# 9      ...                    No                 Yes
# 6      ...                   Yes                  No
# 15     ...                   Yes                 Yes
# 25     ...                   Yes                 Yes
# 21     ...                   Yes                  No
# 20     ...                   Yes                 Yes
#
#                                   Usability Testing.2  \
# 16  As a Product Manager and Business Manager, I b...
# 4   I already chose 3, otherwise I'd like to. Howe...
# 2   We'll have to go through the users' normal eve...
# 14                            too complicated to work
# 19  It is a very effective way for developers to t...
# 18  It can be used to facilitate user observation,...
# 17  This might need a lot of time and iterations i...
# 7   In order to gain insight of whether or not a s...
# 8        This method is similar to User Observation
# 5                                                 TBD
# 23                                      seems useless
# 22    Many situations may not present in statistics.
# 11                       Already have experience with
# 3   I think it's very important to test out the se...
# 13  The result can not represent the all thoughts ...
# 24  Usability testing is a way to see how easy to ...
# 26                                                NaN
# 12  It might be too complicated and time-consuming...
# 10  Usability testing is an important method, but ...
# 1   Although useful, other research methods were m...
# 9   This method would be very beneficial after a w...
# 6   I chose Focus Group, POSTA, and Conjoint Analy...
# 15  I believe that combined with the focus group, ...
# 25     usability is a necessary step in the research
# 21  With my experience this kind of research is ve...
# 20           It can find  problems of products easily
#
#                               Additional?  \
# 16                         Web Analytics.
# 4                                     NaN
# 2                                     NaN
# 14                                    NaN
# 19                                    NaN
# 18                                    NaN
# 17                                    NaN
# 7                                     NaN
# 8   POMES, Focus Group, Conjoint Analysis
# 5                                     NaN
# 23                                    NaN
# 22                                    NaN
# 11                                    NaN
# 3                                     NaN
# 13                                    NaN
# 24                    Maybe SWOT analysis
# 26                                    NaN
# 12                                    n/a
# 10                                    NaN
# 1                                     NaN
# 9                                     NaN
# 6                                     NaN
# 15                                    NaN
# 25                                    NaN
# 21                                    NaN
# 20                                    NaN
#
#                                         Additional?.1 Used GRADES  \
# 16  In my role, I need to understand deeply the cu...  2.0    6.0
# 4                                                 NaN  3.0    8.0
# 2                                                 NaN  3.0    8.0
# 14                                                NaN  8.0    6.0
# 19                                                NaN  7.0    8.0
# 18                                                NaN  3.0    8.0
# 17                                                NaN  3.0    8.0
# 7                                                 NaN  9.0    8.0
# 8   Our next mission is to gather the information ...  3.0    8.0
# 5                                                 NaN  4.0    6.0
# 23                                                NaN  2.0    6.0
# 22                                                NaN  3.0    8.0
# 11                                                NaN  3.0    8.0
# 3                                                 NaN  3.0    8.0
# 13                                                NaN  3.0    8.0
# 24  This method is largely used to discover the st...  3.0    8.0
# 26                                                NaN  NaN    NaN
# 12                                                n/a  3.0    8.0
# 10                                                NaN  3.0    8.0
# 1                                                 NaN  3.0    6.0
# 9                                                 NaN  8.0    8.0
# 6                                                 NaN  3.0    8.0
# 15                                                NaN  3.0    8.0
# 25                                                NaN  3.0    8.0
# 21                                                NaN  6.0    8.0
# 20                                                NaN  2.0    8.0
#
#                              GRADE NOTES FOR STUDENTS  \
# 16  Avoid vague answers. WHY do you feel some meth...
# 4   Overall good job. Some good insights here and ...
# 2   Good job overall. You showed you understand th...
# 14  You need to give more detail about why you are...
# 19  Overall good job. You chose more than 3 method...
# 18  Overall good job. Next time, add more detail t...
# 17  Overall good job. Next time, add more detail t...
# 7   Overall good job! You chose more than 3 method...
# 8   Good job overall. You showed you understand th...
# 5   Please respond to every why question -- TBD is...
# 23  Provide more detail in your answers - you need...
# 22  Good job overall. You showed you understand th...
# 11  Good job overall. Trying new techniques and ch...
# 3   Overall good job. You showed you understand th...
# 13  Overall good job. Some good insights here and ...
# 24  Good job! You demonstrated you understand core...
# 26                                                NaN
# 12  Overall good job. Next time, try to add just a...
# 10  Overall good job. You gave some thoughtful ans...
# 1   Avoid vague answers. Every answer should be di...
# 9   Overall good job. You chose more than 3 method...
# 6   You showed you really understand the methods. ...
# 15  Overall good job. Next time, add more detail t...
# 25  Good job showing that you truly considered eve...
# 21  Overall good job. Next time, add more detail t...
# 20  You showed that you did the work and you also ...
#
#                                              My notes Unnamed: 51
# 16                                                NaN         NaN
# 4                                                 NaN         NaN
# 2                                                 NaN       AEIOU
# 14                                                NaN         NaN
# 19                                                NaN         NaN
# 18                                                NaN         NaN
# 17                           on the fence between 6-8         NaN
# 7                                                 NaN         NaN
# 8                           on the fence between 8-10         NaN
# 5                                                 NaN         NaN
# 23                                                NaN         NaN
# 22                                                NaN         NaN
# 11                                                NaN         NaN
# 3                                                 NaN         NaN
# 13                                                NaN         NaN
# 24                                                NaN         NaN
# 26                                                NaN         NaN
# 12                                                NaN         NaN
# 10  is it ok that gave full effort but some answer...         NaN
# 1                            on the fence between 6-8       AEIOU
# 9                                                 NaN         NaN
# 6   On the fence between 8-10 - great job giving d...         NaN
# 15                                                NaN         NaN
# 25                                                NaN         NaN
# 21                                                NaN         NaN
# 20                                                NaN         NaN
#
# [26 rows x 52 columns]

# %%
modulesData= {"Module": ["Research", "Analysis", "Ideate", "Build", "Communicate"],
             "Module #": [1, 2, 3, 4, 5]}
modules = pd.DataFrame(modulesData)
modules.index = ["MOD_%i" % i for i in range(modules.shape[0])]
modules
# Out:
#             Module  Module #
# MOD_0     Research         1
# MOD_1     Analysis         2
# MOD_2       Ideate         3
# MOD_3        Build         4
# MOD_4  Communicate         5

# %%
consolidatedIndResponses = pd.read_csv('Consolidated Student Responses - Individual.csv', encoding='latin1')[:26]
consolidatedIndResponses.head()
# Out:
#                      Name     Module     Research 1          Research 2  \
# 0    Bezerra, Tiago Tadeu   Research  Web Analytics       1:1 Interview
# 1           Chang, Daniel   Research          POEMS  Competive Analysis
# 2  Chen, Jingling (Lynne)   Research          AEIOU  Competive Analysis
# 3    Chen, Shih Chi (Tim)  Research*            NaN                 NaN
# 4          Chen, Tzu Jung   Research  1:1 Interview    User observation
#
#           Research 3    Module.1         Analysis 1     Analysis 2  \
# 0        Focus Group    Analysis  Why-Low Laddering    Empathy Map
# 1  Conjoint Analysis    Analysis       Powers of 10   How Might We
# 2  Usability Testing    Analysis        Empathy Map       Mind Map
# 3                NaN    Analysis  Why-Low Laddering   Powers of 10
# 4              AEIOU  Analysis**  Why-Low Laddering  Kano Analysis
#
#                  Analysis 3 Module.2          ...            \
# 0  Customer Journey Mapping   Ideate          ...
# 1         Touchpoint Matrix   Ideate          ...
# 2               Concept Map   Ideate          ...
# 3             Task Analysis   Ideate          ...
# 4  Customer Journey Mapping   Ideate          ...
#
#             Ideate 2                      Ideate 3 Module.3    Build 1  \
# 0         Dot Voting  Agile UX Sketching and Scrum    Build  Wireframe
# 1    Weighted Matrix                Design the Box    Build  Wireframe
# 2    Weighted Matrix                Design the Box   Build*  Prototype
# 3  Attribute Listing              The Anti-Problem    Build  Prototype
# 4     Forced Analogy             Design Heuristics    Build  Prototype
#
#                           Build 2                   Build 3       Module.4  \
# 0            Experience Prototype  Customer Journey Mapping  Communicate**
# 1                 Rapid Prototype      Experience Prototype    Communicate
# 2                       Wireframe                 Laser Cut    Communicate
# 3  Laminated Object Manufacturing        Tangible Prototype  Communicate**
# 4                       Wireframe                 Laser Cut    Communicate
#
#          Communicate 1      Communicate 2          Communicate 3
# 0   Envisionment Video  Service Blueprint  Business Model Canvas
# 1          Storyboards     7 Ps Framework               Personas
# 2          Storyboards  Service Blueprint               Personas
# 3                  NaN                NaN                    NaN
# 4  Envisionment Videos  Service Blueprint       Usability Report
#
# [5 rows x 21 columns]

# %%
# Building Student Database
students = im1.sort_values("Name")[["Name", "Email Address"]]
students.index = ["S_%i" % i for i in range(students.shape[0])]
students = students[["Name", "Email Address"]]
students["SID"] = ["S_%i" % i for i in range(students.shape[0])]
students["Email Address"] = students["Email Address"].apply(lambda str: str.lower())
students
# Out:
#                          Name                  Email Address   SID
# S_0      Bezerra, Tiago Tadeu       tiago.tadeu@berkeley.edu   S_0
# S_1             Chang, Daniel          dnlchang@berkeley.edu   S_1
# S_2    Chen, Jingling (Lynne)  chenjingling2017@berkeley.edu   S_2
# S_3      Chen, Shih Chi (Tim)              x841010@gmail.com   S_3
# S_4            Chen, Tzu Jung           tzujung@berkeley.edu   S_4
# S_5                  Feng, Ty            tyfeng@berkeley.edu   S_5
# S_6         Giron, Trisha Mae       trishagiron@berkeley.edu   S_6
# S_7       Guo, Kaifei (Kevin)         guokaifei@berkeley.edu   S_7
# S_8     Han, Kaiyang (Holmes)              1103896880@qq.com   S_8
# S_9              Haupt, Imani          imha0404@berkeley.edu   S_9
# S_10                Hu, Yuxin             7822684021@163.com  S_10
# S_11             Jiao, Yuchen      yuchenjiao95@berkeley.edu  S_11
# S_12     Karchemsky, Mitchell            mkarch@berkeley.edu  S_12
# S_13             Lee, Crystal         c.lee0504@berkeley.edu  S_13
# S_14               Li, Ruixue         ruixeli93@berkeley.edu  S_14
# S_15              Liu, Zelan         eileen1217@berkeley.edu  S_15
# S_16                Lu, Sifan      sophialu0708@berkeley.edu  S_16
# S_17                Min, Rose           rosemin@berkeley.edu  S_17
# S_18           Reese, Michael           mcreese@berkeley.edu  S_18
# S_19             Sagar, Anand       avidyasagar@berkeley.edu  S_19
# S_20  Sanchez Sendiz, Martin       msanchez0406@berkeley.edu  S_20
# S_21    Stamboltsian, Jackie            jakulik@berkeley.edu  S_21
# S_22         Tagliari, Thiago         ttagliari@berkeley.edu  S_22
# S_23  Wang, Zixuan (Charlie)     charliewangzixuan@gmail.com  S_23
# S_24              Xiu, Yuanxi         xiuyuanxi@berkeley.edu  S_24
# S_25            Yen, Yen Tina               v23515@gmail.com  S_25

# %%
# Methods:
# Note: additional methods not asked explicitly about were removed: 
# Affinity Diagram (M3), Dot Voting(M3), Live Prototyping (M4), 3-D Printing (M4)
methods = pd.read_csv('methods.csv', encoding='latin1')
methods.index = ["M_%i" % i for i in range(methods.shape[0])]
methods["MID"] = ["M_%i" % i for i in range(methods.shape[0])]
methods.head()
# Out:
#      Module #    Module                Method  MID
# M_0         1  Research         1:1 Interview  M_0
# M_1         1  Research                 AEIOU  M_1
# M_2         1  Research   Closed Card Sorting  M_2
# M_3         1  Research   Community Appraisal  M_3
# M_4         1  Research  Competitive Analysis  M_4

# %%
# Aggregated Responses by Student
# [SID, Module, Selected Methods (list), Reasons for Selection (list), 
# Unselected Methods (list), Reasons for Unselection (list)]
students['key'] = 1
methods['key'] = 1
indAggResponses = pd.merge(students, methods, on='key')
indAggResponses["Selected"] = 0
indAggResponses["Reason"] = ""
indAggResponses["Familiar"] = 0

# %%
# Adding ISurvey1 into studentResponses
im1s = pd.merge(students, im1, how='inner', on=['Email Address', 'Name'])

mod1Methods = methods[methods["Module #"] == 1]
for method in mod1Methods.Method:
    for SID in im1s["SID"]:
        row = (indAggResponses["SID"] == SID) & (indAggResponses["Method"] == method)
        indAggResponses.loc[row, "Selected"] = (im1s.loc[im1s["SID"] == SID, method + ".1"] == "Yes").values[0]
        indAggResponses.loc[row, "Familiar"] = (im1s.loc[im1s["SID"] == SID, method] == "Yes").values[0]
        indAggResponses.loc[row, "Reason"] = (im1s.loc[im1s["SID"] == SID, method + ".2"]).values[0]

# %%
# Adding All ISurveys into indAggResponses

im2 = pd.read_csv('IM2.csv', encoding='latin1')[1:27]
im3 = pd.read_csv('IM3.csv', encoding='latin1')[1:27]
im4 = pd.read_csv('IM4.csv', encoding='latin1')[1:27]
im5 = pd.read_csv('IM5.csv', encoding='latin1')[1:27]
iSurveys = [im2, im3, im4, im5]

for survey in iSurveys:
    survey.rename(columns={"Unnamed: 1": "Email Address"}, inplace=True)
    survey["Email Address"] = survey["Email Address"].apply(lambda str: str.lower())
    
#im2["Email Address"] = im2["Email Address"].apply(lambda str: str.lower())
#im3["Email Address"] = im3["Email Address"].apply(lambda str: str.lower())
#im4["Email Address"] = im4["Email Address"].apply(lambda str: str.lower())
#im5["Email Address"] = im5["Email Address"].apply(lambda str: str.lower())
iSurveysS = [pd.merge(students, survey, how='inner', on=['Email Address']) for survey in iSurveys]


im1s = pd.merge(students, im1, how='inner', on=['Email Address', 'Name'])
im1s.head()
for i in range(0, 4):
    survey = iSurveysS[i]
    mod1Methods = methods[methods["Module #"] == i + 2]
    for method in mod1Methods.Method:
        for SID in survey["SID"]:
            row = (indAggResponses["SID"] == SID) & (indAggResponses["Method"] == method)
            indAggResponses.loc[row, "Selected"] = (survey.loc[survey["SID"] == SID, method + ".1"] == "Yes").values[0]
            indAggResponses.loc[row, "Familiar"] = (survey.loc[survey["SID"] == SID, method] == "Yes").values[0]
            indAggResponses.loc[row, "Reason"] = (survey.loc[survey["SID"] == SID, method + ".2"]).values[0]

# %%
indAggResponses
# Out:
#                       Name             Email Address   SID  key  Module #  \
# 0     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 1     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 2     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 3     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 4     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 5     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 6     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 7     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 8     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 9     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 10    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 11    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 12    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 13    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         1
# 14    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 15    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 16    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 17    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 18    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 19    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 20    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 21    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 22    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 23    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 24    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 25    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 26    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 27    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 28    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# 29    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1         2
# ...                    ...                       ...   ...  ...       ...
# 1660         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1661         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1662         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1663         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1664         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1665         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1666         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1667         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1668         Yen, Yen Tina          v23515@gmail.com  S_25    1         3
# 1669         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1670         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1671         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1672         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1673         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1674         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1675         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1676         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1677         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1678         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1679         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1680         Yen, Yen Tina          v23515@gmail.com  S_25    1         4
# 1681         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1682         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1683         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1684         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1685         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1686         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1687         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1688         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
# 1689         Yen, Yen Tina          v23515@gmail.com  S_25    1         5
#
#            Module                           Method   MID Selected  \
# 0        Research                    1:1 Interview   M_0     True
# 1        Research                            AEIOU   M_1    False
# 2        Research              Closed Card Sorting   M_2    False
# 3        Research              Community Appraisal   M_3    False
# 4        Research             Competitive Analysis   M_4    False
# 5        Research                Conjoint Analysis   M_5    False
# 6        Research                Conversation Cafe   M_6    False
# 7        Research               Design Ethnography   M_7    False
# 8        Research                      Focus Group   M_8     True
# 9        Research                Open Card Sorting   M_9    False
# 10       Research                            POEMS  M_10    False
# 11       Research                            POSTA  M_11    False
# 12       Research                Usability Testing  M_12    False
# 13       Research                 User Observation  M_13    False
# 14       Analysis                       2x2 Matrix  M_14    False
# 15       Analysis                 Affinity Diagram  M_15    False
# 16       Analysis                          Atomize  M_16    False
# 17       Analysis                  Concept Mapping  M_17    False
# 18       Analysis                  Context Mapping  M_18    False
# 19       Analysis         Customer Journey Mapping  M_19     True
# 20       Analysis                      Empathy Map  M_20     True
# 21       Analysis                     How Might We  M_21    False
# 22       Analysis                    Kano Analysis  M_22    False
# 23       Analysis                     Mind Mapping  M_23    False
# 24       Analysis                     Powers of 10  M_24    False
# 25       Analysis                        Reframing  M_25    False
# 26       Analysis                 Spectrum Mapping  M_26    False
# 27       Analysis                    Task Analysis  M_27    False
# 28       Analysis                Touchpoint Matrix  M_28    False
# 29       Analysis                Why-How Laddering  M_29     True
# ...           ...                              ...   ...      ...
# 1660       Ideate                       Biomimicry  M_35    False
# 1661       Ideate               Borda Count Voting  M_36    False
# 1662       Ideate                    Brainstorming  M_37    False
# 1663       Ideate                Design Heuristics  M_38    False
# 1664       Ideate                   Design the Box  M_39    False
# 1665       Ideate                     Do-Redo-Undo  M_40     True
# 1666       Ideate                   Forced Analogy  M_41    False
# 1667       Ideate             Visual Brainstorming  M_42     True
# 1668       Ideate                  Weighted Matrix  M_43    False
# 1669        Build           Additive Manufacturing  M_44    False
# 1670        Build  Direct Shell Production Casting  M_45    False
# 1671        Build           Experience Prototyping  M_46    False
# 1672        Build       Fused Deposition Modelling  M_47    False
# 1673        Build   Laminated Object Manufacturing  M_48     True
# 1674        Build                    Laser Cutting  M_49    False
# 1675        Build                      Prototyping  M_50     True
# 1676        Build                Rapid Prototyping  M_51    False
# 1677        Build              Service Prototyping  M_52    False
# 1678        Build             Tangible Prototyping  M_53     True
# 1679        Build                Water Jet Cutting  M_54    False
# 1680        Build                        Wireframe  M_55    False
# 1681  Communicate                    7Ps Framework  M_56    False
# 1682  Communicate            Business Model Canvas  M_57     True
# 1683  Communicate             Composite Characters  M_58    False
# 1684  Communicate                   Design Roadmap  M_59    False
# 1685  Communicate               Envisionment Video  M_60    False
# 1686  Communicate                         Personas  M_61     True
# 1687  Communicate                Service Blueprint  M_62    False
# 1688  Communicate                       Storyboard  M_63     True
# 1689  Communicate                 Usability Report  M_64    False
#
#                                                  Reason Familiar
# 0     I've never used this method, despite know abou...     True
# 1     Because in my routine as Product Manager and B...    False
# 2     Because in my routine as Product Manager and B...    False
# 3     As a Product Manager and Business Manager, I b...    False
# 4     As a Product Manager and Business Manager, I b...     True
# 5     As a Product Manager and Business Manager, I b...    False
# 6     As a Product Manager and Business Manager, I b...     True
# 7     Because in my routine as Product Manager and B...    False
# 8     Our business lives a moment to understand more...     True
# 9     Because in my routine as Product Manager and B...    False
# 10    Because in my routine as Product Manager and B...    False
# 11    Because in my routine as Product Manager and B...    False
# 12    As a Product Manager and Business Manager, I b...     True
# 13    As a Product Manager and Business Manager, I b...     True
# 14    I did not know the method. Interesting the app...    False
# 15    Interesting method, did not know it. However, ...    False
# 16    Interesting method, did not know it. However, ...    False
# 17    Interesting method, did not know it. However, ...    False
# 18    Interessante o mÍ©todo, nÍ£o o conhecia. No en...    False
# 19    Fantastic methodology. 100% customer-oriented ...     True
# 20    I have already applied this method in the comp...     True
# 21    I did not know the methodology. I did not choo...    False
# 22    Interesting method, did not know it. However, ...    False
# 23    Interesting method, especially to "get the hea...     True
# 24    I did not know the method. And, frankly, I cou...    False
# 25    I did not know the method. Interesting to appr...    False
# 26    I did not know the method. I did not choose it...    False
# 27    Interesting method, did not know it. However, ...    False
# 28    Interesting method, did not know it. However, ...    False
# 29    This method allows a background in the real re...    False
# ...                                                 ...      ...
# 1660  The process may be inefficient and the solutio...    False
# 1661  It takes time for each idea to be discussed be...    False
# 1662  Team members may feel stressful and unwilling ...    False
# 1663  I may feel  overwhelmed by the large number of...    False
# 1664  It may let team members to focus on salesmansh...    False
# 1665  We only need sticky notes to do this method an...    False
# 1666  It takes time to prepare and conduct a forced ...    False
# 1667  It can solve situations where many ideas have ...    False
# 1668  It is useful when there are several alternativ...    False
# 1669  AM is limited in size and is very expensive. I...    False
# 1670  DSPC is not available commercially yet and it ...    False
# 1671  This method needs to make multiple prototypes ...    False
# 1672  It is similar to laminated object and is slowe...    False
# 1673  LOM is inexpensive and simple. Since our produ...    False
# 1674  Laser Cutting will consume a lot of energy and...    False
# 1675  I can make my idea tangible and real. And it c...    False
# 1676  It needs some skill to use  laser cutter, wate...    False
# 1677  Participants are role-playing so they may not ...    False
# 1678  Materials for this method such as cardboard an...    False
# 1679  I may ruin my design if the material I use is ...    False
# 1680  This method is limited to more interaction and...    False
# 1681  It looks a little similar to Business model ca...    False
# 1682  It is quick to make and easy to understand, sh...    False
# 1683  Combining characters into one user can be a di...    False
# 1684  We may  receive ineffective feedback from othe...    False
# 1685  It takes time to make a video. Besides, we hav...    False
# 1686  It can separate  our team from the users, allo...    False
# 1687  May be hard to interpret with a lack of visual...    False
# 1688  It is an interactive activity that every team ...    False
# 1689  It can be ineffective if all points are not be...    False
#
# [1690 rows x 11 columns]

# %%
indAggResponses[(indAggResponses["Reason"] == "")].groupby(["Module #", "Name"]).size()
# Out:
# Module #  Name
# 4         Giron, Trisha Mae       12
#           Lu, Sifan               12
# 5         Chen, Shih Chi (Tim)     9
#           Lu, Sifan                9
# dtype: int64

# %%
# Team Roster
teamRoster = pd.read_csv('Team Roster.csv', encoding='latin1')[1:28]
teamRoster = pd.merge(teamRoster, students, on = ["Email Address"])
#teams = teams.groupby("Team")
teams = pd.DataFrame(columns = ["Team", "SID"])
for row in teamRoster[["Team", "SID", "Name"]].groupby("Team"):
    print(type(row[1]))
    print(row[1].SID.values)
    teams.loc[teams.shape[0]] = [row[0], row[1].SID.values]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['S_8' 'S_13' 'S_20' 'S_25']
# <class 'pandas.core.frame.DataFrame'>
# ['S_2' 'S_7' 'S_10' 'S_15']
# <class 'pandas.core.frame.DataFrame'>
# ['S_9' 'S_11' 'S_17' 'S_18' 'S_23']
# <class 'pandas.core.frame.DataFrame'>
# ['S_1' 'S_12' 'S_14' 'S_16']
# <class 'pandas.core.frame.DataFrame'>
# ['S_4' 'S_3' 'S_6' 'S_21']
# <class 'pandas.core.frame.DataFrame'>
# ['S_5' 'S_19' 'S_22' 'S_24']

# %%
teams.loc[[False, True, True, True, True]]
# Out:
#      Team                            SID
# 1  Team 2         [S_2, S_7, S_10, S_15]
# 2  Team 3  [S_9, S_11, S_17, S_18, S_23]
# 3  Team 4        [S_1, S_12, S_14, S_16]
# 4  Team 5          [S_4, S_3, S_6, S_21]

# %%
# Team Aggregate Responses
# Team, Module, Chosen Method (3 rows per team), Reason, Decision Process

teamAggResponses = pd.DataFrame(columns = ["Team", "Module", "Chosen Method", "Reason", "Decision Process"])

# %%
teamAggResponses = pd.DataFrame(columns = ["Team", "Module", "Chosen Method", "Reason", "Decision Process"])

# Note: deleted extra responses from team 1
tm1 = pd.read_csv('TM1.csv', encoding='latin1')
tm1

teamData = [pd.read_csv('TM%d.csv' % i, encoding='latin1') for i in range(1,5 + 1)]

for i in range(1, 5+1):
    team = teamData[i-1]
    for r in range(tm1.shape[0]):
        for q in range(0, 3):
            ri = teamAggResponses.shape[0] # + 1, + 2
            teamAggResponses.loc[ri, "Module"] = i
            teamAggResponses.loc[ri, "Team"] = team[team.columns[1]][r]
            teamAggResponses.loc[ri, "Chosen Method"] = team[team.columns[q*3 + 2]][r]
            teamAggResponses.loc[ri, "Reason"] = team[team.columns[q*3 + 4]][r]
            teamAggResponses.loc[ri, "Decision Process"] = team[team.columns[q*3 + 3]][r]

# %%
teamAggResponses
# Out:
#       Team Module             Chosen Method  \
# 0   Team 1      1             1:1 Interview
# 1   Team 1      1         Open Card Sorting
# 2   Team 1      1                     AEIOU
# 3   Team 2      1             1:1 Interview
# 4   Team 2      1       Community Appraisal
# 5   Team 2      1         Usability Testing
# 6   Team 3      1                     AEIOU
# 7   Team 3      1      Competitive Analysis
# 8   Team 3      1             1:1 Interview
# 9   Team 4      1             1:1 Interview
# 10  Team 4      1      Competitive Analysis
# 11  Team 4      1                     AEIOU
# 12  Team 5      1                     AEIOU
# 13  Team 5      1          User Observation
# 14  Team 5      1             1:1 Interview
# 15  Team 6      1          User Observation
# 16  Team 6      1             1:1 Interview
# 17  Team 6      1                     AEIOU
# 18  Team 1      2               Empathy Map
# 19  Team 1      2      Affinity Diagramming
# 20  Team 1      2               Concept Map
# 21  Team 2      2               Empathy Map
# 22  Team 2      2                  Mind Map
# 23  Team 2      2                2x2 Matrix
# 24  Team 3      2               Concept Map
# 25  Team 3      2             Task Analysis
# 26  Team 3      2  Customer Journey Mapping
# 27  Team 4      2                 Reframing
# 28  Team 4      2                   Atomize
# 29  Team 4      2                2x2 Matrix
# ..     ...    ...                       ...
# 60  Team 3      4                 Wireframe
# 61  Team 3      4               Prototyping
# 62  Team 3      4         Service Prototype
# 63  Team 3      4               Prototyping
# 64  Team 3      4         Service Prototype
# 65  Team 3      4                 Wireframe
# 66  Team 4      4                 Wireframe
# 67  Team 4      4        Tangible Prototype
# 68  Team 4      4         Rapid Prototyping
# 69  Team 5      4                 Wireframe
# 70  Team 5      4               Prototyping
# 71  Team 5      4      Experience Prototype
# 72  Team 1      5            Design Roadmap
# 73  Team 1      5               Storyboards
# 74  Team 1      5            7 Ps Framework
# 75  Team 2      5                  Personas
# 76  Team 2      5            Design Roadmap
# 77  Team 2      5            7 Ps Framework
# 78  Team 3      5      Composite Characters
# 79  Team 3      5               Storyboards
# 80  Team 3      5            Design Roadmap
# 81  Team 4      5                  Personas
# 82  Team 4      5               Storyboards
# 83  Team 4      5          Usability Report
# 84  Team 5      5       Envisionment Videos
# 85  Team 5      5         Service Blueprint
# 86  Team 5      5            Design Roadmap
# 87  Team 6      5            Design Roadmap
# 88  Team 6      5               Storyboards
# 89  Team 6      5      Composite Characters
#
#                                                Reason  \
# 0   Since our team is focusing on creating a produ...
# 1   We decided to go with the open card sorting me...
# 2   The AEIOU method will allow us to observe unde...
# 3   We are trying to improve the current medical p...
# 4   Since we would like encourage a sense of commu...
# 5   Our problems requires that two sets of user wi...
# 6   Factors important to this method is the amount...
# 7   Overall, the reason why competitive analysis w...
# 8   As previously mentioned in the last question, ...
# 9   Since we are using AEIOU and competitive analy...
# 10  Our target population, at the moment, consists...
# 11  Finally, we felt AEIOU, helped us to identify ...
# 12  We considered similar methods (POSTA/POEMS) an...
# 13  As we're trying to get information on BART rid...
# 14  For this one we considered the ease of impleme...
# 15  The first factor we considered when choosing o...
# 16  We considered how well it complemented the oth...
# 17  AEIOU emphasizes on activities that users do, ...
# 18  Since we are aiming to help alleviate some of ...
# 19  After out 1:1 interviews, our team had a lot o...
# 20  Our main motivator for choosing concept mappin...
# 21  Do: 1. My medical apartments have CCTV to reco...
# 22  It's really hard to start from the first/early...
# 23  2x2 Matrix can provide a clear view of the cur...
# 24   The two primary reasons that our team decided...
# 25  We decided on this method primarily because of...
# 26  .Factors that were considered for this approac...
# 27  Our research focused on a fairly specific issu...
# 28  Atomization seems like a natural extension of ...
# 29  As previously mentioned, during class, our use...
# ..                                                ...
# 60  We chose wireframe as our build method mainly ...
# 61  The main factors that contributed to our decis...
# 62  The factors that contributed to our decision w...
# 63  The main factors that contributed to our decis...
# 64  The factors that contributed to our decision w...
# 65  We considered the amount of features in our ap...
# 66  Our design solution requires  both  a smart st...
# 67  The vision for our design solution is very gro...
# 68  Given the length of the class, some of the mor...
# 69  We needed a way to visualize the mobile design...
# 70  We needed a way to validate and demonstrate th...
# 71  The App that weâre designing has various fea...
# 72     After the second peer review, we received s...
# 73  \tWhen choosing the storyboarding method, our ...
# 74   Since we have been through our design process...
# 75  With module design, the medicine storage can b...
# 76  The factor we consider is easy to express how ...
# 77  When we are choosing methods, we think that th...
# 78  Our team elected to use a composite character ...
# 79  The two primary reasons that our team decided ...
# 80  Danielle told us that the primary benefit of t...
# 81  We believe that personas are important in that...
# 82  As mentioned above, we valued the visual aspec...
# 83  As mentioned previously, this method directly ...
# 84  We have members in our group that have experie...
# 85  This method makes sense to use because our pro...
# 86  Our group has members which are apt at storyte...
# 87  We believed that this is a great method to sho...
# 88  We believed that this would be a great method ...
# 89  We believe that composite characters would hel...
#
#                                      Decision Process
# 0   Our team agreed to use the 1:1 Interview metho...
# 1   Initially, our team was choosing between close...
# 2   We decided that the AEIOU method would enable ...
# 3   Since we all come from different background. E...
# 4   There is a strong argument to be made about wh...
# 5   The identified problem(s) involve two sets of ...
# 6   Using AEIOU as a Method of research could be h...
# 7   Our team decided to conduct competitive analys...
# 8   Our team compared all the methodologies and dr...
# 9   We knew that it would be important to get deep...
# 10  Once we have determined the design space we fi...
# 11  We believe that it is important to look at all...
# 12  We discussed this as a group over online chat,...
# 13  Similar to the way we decided on method 1, we ...
# 14  Again, we discussed the benefits and limitatio...
# 15  With user observation, we can collect raw insi...
# 16  It provides useful insight into our clients an...
# 17  We decided to use this method because we neede...
# 18  All members of the team unanimously decided to...
# 19  The members in our group are all creative, and...
# 20  After considering other methods for analysis, ...
# 21  Empathy map is a efficient method to organize ...
# 22  Mind map is a quick way to generate and organi...
# 23  Since there are lots of products in the market...
# 24  Our team decided on using the concept map meth...
# 25  After evaluating all the options and pictured ...
# 26  Charlie proposed this method and we all at the...
# 27  After having finished the research, we tried t...
# 28  Again, in trying to find design methods that c...
# 29  While we initially did not select this method,...
# ..                                                ...
# 60  Wireframes visually depict the rudimentary lay...
# 61  In ideate step, we brainstormed many ideas and...
# 62  Allowing users to go through the service allow...
# 63  In ideate step, we brainstormed many ideas and...
# 64  Allowing users to go through the service allow...
# 65  Wire framing was best because we had an app. I...
# 66  Wireframe is the build method given that most ...
# 67  While building a full scale street lamp seems ...
# 68  This method goes hand in hand with our necessi...
# 69  We agreed on this method the quickest because ...
# 70  Undoubtedly, we need this method to make ours ...
# 71  The development of the product is currently on...
# 72        Our team has some confusion and uncertai...
# 73  \tThrough group discussion, our team agreed th...
# 74   The team agreed that this method would clearl...
# 75  Our team made up a character to better improve...
# 76  We wanted something that can track our process...
# 77  It has a lot to do with purpose, product, peop...
# 78  Our group firstly consider the university of o...
# 79  At very beginning, our team opted to using sto...
# 80  Our team decided to use Design road mapping as...
# 81  Since we had used personas in our role play as...
# 82  We wanted to ensure we included at least 1 vis...
# 83  Our team found this method interesting in how ...
# 84  A few of us chose this method in our individua...
# 85  Someone suggested this method and others agree...
# 86  We had a team discussion and readily agreed to...
# 87  We quickly agreed on using a design roadmap as...
# 88  As a group, we discussed which all methods we ...
# 89  As a group, we discussed which all methods we ...
#
# [90 rows x 5 columns]
