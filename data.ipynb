# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import style

# %%
im1 = pd.read_csv('IM1.csv', encoding='latin1')[1:27]
im1["Email Address"] = im1["Email Address"].apply(lambda str: str.lower())
im1.sort_values("Name")
# Out:
#         Timestamp                  Email Address                     Name  \
# 16   7/9/17 16:23       tiago.tadeu@berkeley.edu     Bezerra, Tiago Tadeu
# 4    7/11/17 0:18          dnlchang@berkeley.edu            Chang, Daniel
# 2   7/10/17 21:15  chenjingling2017@berkeley.edu   Chen, Jingling (Lynne)
# 14  7/10/17 22:47              x841010@gmail.com     Chen, Shih Chi (Tim)
# 19   7/11/17 7:54           tzujung@berkeley.edu           Chen, Tzu Jung
# 18  7/11/17 12:26            tyfeng@berkeley.edu                 Feng, Ty
# 17   7/11/17 3:00       trishagiron@berkeley.edu        Giron, Trisha Mae
# 7   7/12/17 21:02         guokaifei@berkeley.edu      Guo, Kaifei (Kevin)
# 8   7/10/17 15:40              1103896880@qq.com    Han, Kaiyang (Holmes)
# 5    7/11/17 0:32          imha0404@berkeley.edu             Haupt, Imani
# 23   7/9/17 17:28             7822684021@163.com                Hu, Yuxin
# 22  7/10/17 20:08      yuchenjiao95@berkeley.edu             Jiao, Yuchen
# 11  7/10/17 20:19            mkarch@berkeley.edu     Karchemsky, Mitchell
# 3    7/11/17 1:01         c.lee0504@berkeley.edu             Lee, Crystal
# 13   7/11/17 0:17         ruixeli93@berkeley.edu               Li, Ruixue
# 24  7/10/17 14:51        eileen1217@berkeley.edu              Liu, Zelan
# 26            NaN      sophialu0708@berkeley.edu                Lu, Sifan
# 12   7/11/17 0:19           rosemin@berkeley.edu                Min, Rose
# 10  7/10/17 19:57           mcreese@berkeley.edu           Reese, Michael
# 1   7/10/17 18:14       avidyasagar@berkeley.edu             Sagar, Anand
# 9    7/11/17 8:16      msanchez0406@berkeley.edu  Sanchez Sendiz, Martin
# 6   7/10/17 21:35           jakulik@berkeley.edu    Stamboltsian, Jackie
# 15   7/11/17 0:58         ttagliari@berkeley.edu         Tagliari, Thiago
# 25  7/10/17 11:59    charliewangzixuan@gmail.com  Wang, Zixuan (Charlie)
# 21   7/11/17 9:50         xiuyuanxi@berkeley.edu              Xiu, Yuanxi
# 20  7/10/17 12:15               v23515@gmail.com            Yen, Yen Tina
#
#    AEIOU AEIOU.1                                            AEIOU.2 POEMS  \
# 16    No      No  Because in my routine as Product Manager and B...    No
# 4     No      No  It does not take location based information in...    No
# 2    Yes     Yes  Because it can be heuristic and be a guideline...   Yes
# 14    No     Yes  It's a comprehensive method that can make sure...    No
# 19    No      No  AEIOU is a research method mostly focuses on c...    No
# 18    No      No  AEIOU is needed when simplifying large amounts...   Yes
# 17    No     Yes  It gives a good framework for organizing and i...    No
# 7     No     Yes  Observations are everywhere and of various kin...    No
# 8     No      No  The benefit of this method is not suitable for...   Yes
# 5     No      No  Don't use it may in the future but It is not f...    No
# 23   Yes      No  Because it seems much clearer to figure out wh...    No
# 22    No      No  The AEIOU is too precise and limited which is ...    No
# 11   Yes     Yes  I like that AEIOU focuses on a more holistic a...    No
# 3     No      No  I didn't chose this method because it's situat...    No
# 13    No      No  This method is not suitable for big picture ca...    No
# 24    No     Yes  AEIOU consists of 5 elements: activity, enviro...    No
# 26   NaN     NaN                                                NaN   NaN
# 12    No     Yes  Despite its limitations of not being able to c...    No
# 10    No     Yes  The selection of AEIOU is based on a desire to...    No
# 1     No     Yes         It is a useful way to organize information    No
# 9     No     Yes  This method would allow me to keep my observat...    No
# 6     No      No       I chose POSTA, a similar method, over AEIOU.    No
# 15    No      No  Because it limits you in some precise situatio...    No
# 25   Yes     Yes  AEIOU is a coding structure mnemonic used to o...    No
# 21   Yes     Yes  It concludes all main elements of a thing. It'...    No
# 20    No      No                               It takes a long time    No
#
#    POEMS.1                                            POEMS.2 POSTA  \
# 16      No  Because in my routine as Product Manager and B...    No
# 4      Yes  Seems to provide a fairly broad foundation for...    No
# 2       No    It has some simiarities with the methods AEIOU.   Yes
# 14      No              cant figure out what exactly it means    No
# 19     Yes  POEMS helps researcher to capture specific pie...    No
# 18      No  POEMS is needed when learning about new unfami...    No
# 17      No  It does not strike too much as something that ...    No
# 7      Yes  To organize observations, it is often better t...    No
# 8      Yes  After we get information, we need to analysis ...   Yes
# 5       No                      Not enough information on it.    No
# 23      No                 It seems much more mess than AEIOU    No
# 22      No      The gathered information may be too trivial.     No
# 11      No  I feel like i'll be using this in sort of a mi...    No
# 3       No  I did not choose this method because I prefer ...    No
# 13     Yes  This method can help researchers to understand...    No
# 24      No  This method also consists of 5 elements: peopl...    No
# 26     NaN                                                NaN   NaN
# 12      No  I did not choose it because I did not have eno...    No
# 10      No  I feel as if POEMS is a more general method, w...    No
# 1       No                         It did not seem worthwhile    No
# 9       No  The method is similar to AEIOU but categorizes...    No
# 6       No    I chose POSTA, a related method, over this one.    No
# 15      No  Because this method limits you in some precise...    No
# 25      No  POEMS framework family research should be done...    No
# 21      No  I think my thinking mode is more same as AEIOU...   Yes
# 20      No                 It needs great observation ability    No
#
#        ...     Usability Testing Usability Testing.1  \
# 16     ...                   Yes                  No
# 4      ...                    No                  No
# 2      ...                   Yes                 Yes
# 14     ...                    No                  No
# 19     ...                   Yes                 Yes
# 18     ...                   Yes                  No
# 17     ...                   Yes                  No
# 7      ...                   Yes                 Yes
# 8      ...                    No                  No
# 5      ...                    No                  No
# 23     ...                    No                  No
# 22     ...                    No                  No
# 11     ...                   Yes                  No
# 3      ...                    No                 Yes
# 13     ...                    No                  No
# 24     ...                   Yes                  No
# 26     ...                   NaN                 NaN
# 12     ...                   Yes                  No
# 10     ...                   Yes                  No
# 1      ...                    No                  No
# 9      ...                    No                 Yes
# 6      ...                   Yes                  No
# 15     ...                   Yes                 Yes
# 25     ...                   Yes                 Yes
# 21     ...                   Yes                  No
# 20     ...                   Yes                 Yes
#
#                                   Usability Testing.2  \
# 16  As a Product Manager and Business Manager, I b...
# 4   I already chose 3, otherwise I'd like to. Howe...
# 2   We'll have to go through the users' normal eve...
# 14                            too complicated to work
# 19  It is a very effective way for developers to t...
# 18  It can be used to facilitate user observation,...
# 17  This might need a lot of time and iterations i...
# 7   In order to gain insight of whether or not a s...
# 8        This method is similar to User Observation
# 5                                                 TBD
# 23                                      seems useless
# 22    Many situations may not present in statistics.
# 11                       Already have experience with
# 3   I think it's very important to test out the se...
# 13  The result can not represent the all thoughts ...
# 24  Usability testing is a way to see how easy to ...
# 26                                                NaN
# 12  It might be too complicated and time-consuming...
# 10  Usability testing is an important method, but ...
# 1   Although useful, other research methods were m...
# 9   This method would be very beneficial after a w...
# 6   I chose Focus Group, POSTA, and Conjoint Analy...
# 15  I believe that combined with the focus group, ...
# 25     usability is a necessary step in the research
# 21  With my experience this kind of research is ve...
# 20           It can find  problems of products easily
#
#                               Additional?  \
# 16                         Web Analytics.
# 4                                     NaN
# 2                                     NaN
# 14                                    NaN
# 19                                    NaN
# 18                                    NaN
# 17                                    NaN
# 7                                     NaN
# 8   POMES, Focus Group, Conjoint Analysis
# 5                                     NaN
# 23                                    NaN
# 22                                    NaN
# 11                                    NaN
# 3                                     NaN
# 13                                    NaN
# 24                    Maybe SWOT analysis
# 26                                    NaN
# 12                                    n/a
# 10                                    NaN
# 1                                     NaN
# 9                                     NaN
# 6                                     NaN
# 15                                    NaN
# 25                                    NaN
# 21                                    NaN
# 20                                    NaN
#
#                                         Additional?.1 Used GRADES  \
# 16  In my role, I need to understand deeply the cu...  2.0    6.0
# 4                                                 NaN  3.0    8.0
# 2                                                 NaN  3.0    8.0
# 14                                                NaN  8.0    6.0
# 19                                                NaN  7.0    8.0
# 18                                                NaN  3.0    8.0
# 17                                                NaN  3.0    8.0
# 7                                                 NaN  9.0    8.0
# 8   Our next mission is to gather the information ...  3.0    8.0
# 5                                                 NaN  4.0    6.0
# 23                                                NaN  2.0    6.0
# 22                                                NaN  3.0    8.0
# 11                                                NaN  3.0    8.0
# 3                                                 NaN  3.0    8.0
# 13                                                NaN  3.0    8.0
# 24  This method is largely used to discover the st...  3.0    8.0
# 26                                                NaN  NaN    NaN
# 12                                                n/a  3.0    8.0
# 10                                                NaN  3.0    8.0
# 1                                                 NaN  3.0    6.0
# 9                                                 NaN  8.0    8.0
# 6                                                 NaN  3.0    8.0
# 15                                                NaN  3.0    8.0
# 25                                                NaN  3.0    8.0
# 21                                                NaN  6.0    8.0
# 20                                                NaN  2.0    8.0
#
#                              GRADE NOTES FOR STUDENTS  \
# 16  Avoid vague answers. WHY do you feel some meth...
# 4   Overall good job. Some good insights here and ...
# 2   Good job overall. You showed you understand th...
# 14  You need to give more detail about why you are...
# 19  Overall good job. You chose more than 3 method...
# 18  Overall good job. Next time, add more detail t...
# 17  Overall good job. Next time, add more detail t...
# 7   Overall good job! You chose more than 3 method...
# 8   Good job overall. You showed you understand th...
# 5   Please respond to every why question -- TBD is...
# 23  Provide more detail in your answers - you need...
# 22  Good job overall. You showed you understand th...
# 11  Good job overall. Trying new techniques and ch...
# 3   Overall good job. You showed you understand th...
# 13  Overall good job. Some good insights here and ...
# 24  Good job! You demonstrated you understand core...
# 26                                                NaN
# 12  Overall good job. Next time, try to add just a...
# 10  Overall good job. You gave some thoughtful ans...
# 1   Avoid vague answers. Every answer should be di...
# 9   Overall good job. You chose more than 3 method...
# 6   You showed you really understand the methods. ...
# 15  Overall good job. Next time, add more detail t...
# 25  Good job showing that you truly considered eve...
# 21  Overall good job. Next time, add more detail t...
# 20  You showed that you did the work and you also ...
#
#                                              My notes Unnamed: 51
# 16                                                NaN         NaN
# 4                                                 NaN         NaN
# 2                                                 NaN       AEIOU
# 14                                                NaN         NaN
# 19                                                NaN         NaN
# 18                                                NaN         NaN
# 17                           on the fence between 6-8         NaN
# 7                                                 NaN         NaN
# 8                           on the fence between 8-10         NaN
# 5                                                 NaN         NaN
# 23                                                NaN         NaN
# 22                                                NaN         NaN
# 11                                                NaN         NaN
# 3                                                 NaN         NaN
# 13                                                NaN         NaN
# 24                                                NaN         NaN
# 26                                                NaN         NaN
# 12                                                NaN         NaN
# 10  is it ok that gave full effort but some answer...         NaN
# 1                            on the fence between 6-8       AEIOU
# 9                                                 NaN         NaN
# 6   On the fence between 8-10 - great job giving d...         NaN
# 15                                                NaN         NaN
# 25                                                NaN         NaN
# 21                                                NaN         NaN
# 20                                                NaN         NaN
#
# [26 rows x 52 columns]

# %%
modulesData= {"Module": ["Research", "Analysis", "Ideate", "Build", "Communicate"],
             "Module #": [1, 2, 3, 4, 5]}
modules = pd.DataFrame(modulesData)
modules.index = ["MOD_%i" % i for i in range(modules.shape[0])]
modules
# Out:
#             Module  Module #
# MOD_0     Research         1
# MOD_1     Analysis         2
# MOD_2       Ideate         3
# MOD_3        Build         4
# MOD_4  Communicate         5

# %%
consolidatedIndResponses = pd.read_csv('Consolidated Student Responses - Individual.csv', encoding='latin1')[:26]
consolidatedIndResponses.head()
# Out:
#                      Name     Module     Research 1          Research 2  \
# 0    Bezerra, Tiago Tadeu   Research  Web Analytics       1:1 Interview
# 1           Chang, Daniel   Research          POEMS  Competive Analysis
# 2  Chen, Jingling (Lynne)   Research          AEIOU  Competive Analysis
# 3    Chen, Shih Chi (Tim)  Research*            NaN                 NaN
# 4          Chen, Tzu Jung   Research  1:1 Interview    User observation
#
#           Research 3    Module.1         Analysis 1     Analysis 2  \
# 0        Focus Group    Analysis  Why-Low Laddering    Empathy Map
# 1  Conjoint Analysis    Analysis       Powers of 10   How Might We
# 2  Usability Testing    Analysis        Empathy Map       Mind Map
# 3                NaN    Analysis  Why-Low Laddering   Powers of 10
# 4              AEIOU  Analysis**  Why-Low Laddering  Kano Analysis
#
#                  Analysis 3 Module.2          ...            \
# 0  Customer Journey Mapping   Ideate          ...
# 1         Touchpoint Matrix   Ideate          ...
# 2               Concept Map   Ideate          ...
# 3             Task Analysis   Ideate          ...
# 4  Customer Journey Mapping   Ideate          ...
#
#             Ideate 2                      Ideate 3 Module.3    Build 1  \
# 0         Dot Voting  Agile UX Sketching and Scrum    Build  Wireframe
# 1    Weighted Matrix                Design the Box    Build  Wireframe
# 2    Weighted Matrix                Design the Box   Build*  Prototype
# 3  Attribute Listing              The Anti-Problem    Build  Prototype
# 4     Forced Analogy             Design Heuristics    Build  Prototype
#
#                           Build 2                   Build 3       Module.4  \
# 0            Experience Prototype  Customer Journey Mapping  Communicate**
# 1                 Rapid Prototype      Experience Prototype    Communicate
# 2                       Wireframe                 Laser Cut    Communicate
# 3  Laminated Object Manufacturing        Tangible Prototype  Communicate**
# 4                       Wireframe                 Laser Cut    Communicate
#
#          Communicate 1      Communicate 2          Communicate 3
# 0   Envisionment Video  Service Blueprint  Business Model Canvas
# 1          Storyboards     7 Ps Framework               Personas
# 2          Storyboards  Service Blueprint               Personas
# 3                  NaN                NaN                    NaN
# 4  Envisionment Videos  Service Blueprint       Usability Report
#
# [5 rows x 21 columns]

# %%
# Building Student Database
students = im1.sort_values("Name")[["Name", "Email Address"]]
students.index = ["S_%i" % i for i in range(students.shape[0])]
students = students[["Name", "Email Address"]]
students["SID"] = ["S_%i" % i for i in range(students.shape[0])]
students["Email Address"] = students["Email Address"].apply(lambda str: str.lower())
students
# Out:
#                          Name                  Email Address   SID
# S_0      Bezerra, Tiago Tadeu       tiago.tadeu@berkeley.edu   S_0
# S_1             Chang, Daniel          dnlchang@berkeley.edu   S_1
# S_2    Chen, Jingling (Lynne)  chenjingling2017@berkeley.edu   S_2
# S_3      Chen, Shih Chi (Tim)              x841010@gmail.com   S_3
# S_4            Chen, Tzu Jung           tzujung@berkeley.edu   S_4
# S_5                  Feng, Ty            tyfeng@berkeley.edu   S_5
# S_6         Giron, Trisha Mae       trishagiron@berkeley.edu   S_6
# S_7       Guo, Kaifei (Kevin)         guokaifei@berkeley.edu   S_7
# S_8     Han, Kaiyang (Holmes)              1103896880@qq.com   S_8
# S_9              Haupt, Imani          imha0404@berkeley.edu   S_9
# S_10                Hu, Yuxin             7822684021@163.com  S_10
# S_11             Jiao, Yuchen      yuchenjiao95@berkeley.edu  S_11
# S_12     Karchemsky, Mitchell            mkarch@berkeley.edu  S_12
# S_13             Lee, Crystal         c.lee0504@berkeley.edu  S_13
# S_14               Li, Ruixue         ruixeli93@berkeley.edu  S_14
# S_15              Liu, Zelan         eileen1217@berkeley.edu  S_15
# S_16                Lu, Sifan      sophialu0708@berkeley.edu  S_16
# S_17                Min, Rose           rosemin@berkeley.edu  S_17
# S_18           Reese, Michael           mcreese@berkeley.edu  S_18
# S_19             Sagar, Anand       avidyasagar@berkeley.edu  S_19
# S_20  Sanchez Sendiz, Martin       msanchez0406@berkeley.edu  S_20
# S_21    Stamboltsian, Jackie            jakulik@berkeley.edu  S_21
# S_22         Tagliari, Thiago         ttagliari@berkeley.edu  S_22
# S_23  Wang, Zixuan (Charlie)     charliewangzixuan@gmail.com  S_23
# S_24              Xiu, Yuanxi         xiuyuanxi@berkeley.edu  S_24
# S_25            Yen, Yen Tina               v23515@gmail.com  S_25

# %%
# Methods:
# Note: additional methods not asked explicitly about were removed: 
# Affinity Diagram (M3), Dot Voting(M3), Live Prototyping (M4), 3-D Printing (M4)
methods = pd.read_csv('methods.csv', encoding='latin1')
#methods.index = ["M_%i" % i for i in range(methods.shape[0])]
methods["MID"] = ["M_%i" % i for i in range(methods.shape[0])]
methods
# Out:
#    Unnamed: 0 Unnamed: 0.1  Module #       Module  \
# 0         M_0          M_0         1     Research
# 1         M_1          M_1         1     Research
# 2         M_2          M_2         1     Research
# 3         M_3          M_3         1     Research
# 4         M_4          M_4         1     Research
# 5         M_5          M_5         1     Research
# 6         M_6          M_6         1     Research
# 7         M_7          M_7         1     Research
# 8         M_8          M_8         1     Research
# 9         M_9          M_9         1     Research
# 10       M_10         M_10         1     Research
# 11       M_11         M_11         1     Research
# 12       M_12         M_12         1     Research
# 13       M_13         M_13         1     Research
# 14       M_14         M_14         2     Analysis
# 15       M_15         M_15         2     Analysis
# 16       M_16         M_16         2     Analysis
# 17       M_17         M_17         2     Analysis
# 18       M_18         M_18         2     Analysis
# 19       M_19         M_19         2     Analysis
# 20       M_20         M_20         2     Analysis
# 21       M_21         M_21         2     Analysis
# 22       M_22         M_22         2     Analysis
# 23       M_23         M_23         2     Analysis
# 24       M_24         M_24         2     Analysis
# 25       M_25         M_25         2     Analysis
# 26       M_26         M_26         2     Analysis
# 27       M_27         M_27         2     Analysis
# 28       M_28         M_28         2     Analysis
# 29       M_29         M_29         2     Analysis
# ..        ...          ...       ...          ...
# 35       M_35         M_35         3       Ideate
# 36       M_36         M_36         3       Ideate
# 37       M_37         M_37         3       Ideate
# 38       M_38         M_38         3       Ideate
# 39       M_39         M_39         3       Ideate
# 40       M_40         M_40         3       Ideate
# 41       M_41         M_41         3       Ideate
# 42       M_42         M_42         3       Ideate
# 43       M_43         M_43         3       Ideate
# 44       M_44         M_44         4        Build
# 45       M_45         M_45         4        Build
# 46       M_46         M_46         4        Build
# 47       M_47         M_47         4        Build
# 48       M_48         M_48         4        Build
# 49       M_49         M_49         4        Build
# 50       M_50         M_50         4        Build
# 51       M_51         M_51         4        Build
# 52       M_52         M_52         4        Build
# 53       M_53         M_53         4        Build
# 54       M_54         M_54         4        Build
# 55       M_55         M_55         4        Build
# 56       M_56         M_56         5  Communicate
# 57       M_57         M_57         5  Communicate
# 58       M_58         M_58         5  Communicate
# 59       M_59         M_59         5  Communicate
# 60       M_60         M_60         5  Communicate
# 61       M_61         M_61         5  Communicate
# 62       M_62         M_62         5  Communicate
# 63       M_63         M_63         5  Communicate
# 64       M_64         M_64         5  Communicate
#
#                              Method   MID  key
# 0                     1:1 Interview   M_0    1
# 1                             AEIOU   M_1    1
# 2               Closed Card Sorting   M_2    1
# 3               Community Appraisal   M_3    1
# 4              Competitive Analysis   M_4    1
# 5                 Conjoint Analysis   M_5    1
# 6                 Conversation Cafe   M_6    1
# 7                Design Ethnography   M_7    1
# 8                       Focus Group   M_8    1
# 9                 Open Card Sorting   M_9    1
# 10                            POEMS  M_10    1
# 11                            POSTA  M_11    1
# 12                Usability Testing  M_12    1
# 13                 User Observation  M_13    1
# 14                       2x2 Matrix  M_14    1
# 15                 Affinity Diagram  M_15    1
# 16                          Atomize  M_16    1
# 17                  Concept Mapping  M_17    1
# 18                  Context Mapping  M_18    1
# 19         Customer Journey Mapping  M_19    1
# 20                      Empathy Map  M_20    1
# 21                     How Might We  M_21    1
# 22                    Kano Analysis  M_22    1
# 23                     Mind Mapping  M_23    1
# 24                     Powers of 10  M_24    1
# 25                        Reframing  M_25    1
# 26                 Spectrum Mapping  M_26    1
# 27                    Task Analysis  M_27    1
# 28                Touchpoint Matrix  M_28    1
# 29                Why-How Laddering  M_29    1
# ..                              ...   ...  ...
# 35                       Biomimicry  M_35    1
# 36               Borda Count Voting  M_36    1
# 37                    Brainstorming  M_37    1
# 38                Design Heuristics  M_38    1
# 39                   Design the Box  M_39    1
# 40                     Do-Redo-Undo  M_40    1
# 41                   Forced Analogy  M_41    1
# 42             Visual Brainstorming  M_42    1
# 43                  Weighted Matrix  M_43    1
# 44           Additive Manufacturing  M_44    1
# 45  Direct Shell Production Casting  M_45    1
# 46           Experience Prototyping  M_46    1
# 47       Fused Deposition Modelling  M_47    1
# 48   Laminated Object Manufacturing  M_48    1
# 49                    Laser Cutting  M_49    1
# 50                      Prototyping  M_50    1
# 51                Rapid Prototyping  M_51    1
# 52              Service Prototyping  M_52    1
# 53             Tangible Prototyping  M_53    1
# 54                Water Jet Cutting  M_54    1
# 55                        Wireframe  M_55    1
# 56                    7Ps Framework  M_56    1
# 57            Business Model Canvas  M_57    1
# 58             Composite Characters  M_58    1
# 59                   Design Roadmap  M_59    1
# 60               Envisionment Video  M_60    1
# 61                         Personas  M_61    1
# 62                Service Blueprint  M_62    1
# 63                       Storyboard  M_63    1
# 64                 Usability Report  M_64    1
#
# [65 rows x 7 columns]

# %%
# Aggregated Responses by Student
# [SID, Module, Selected Methods (list), Reasons for Selection (list), 
# Unselected Methods (list), Reasons for Unselection (list)]
students['key'] = 1
methods['key'] = 1
indAggResponses = pd.merge(students, methods, on='key')
indAggResponses["Selected"] = 0
indAggResponses["Reason"] = ""
indAggResponses["Familiar"] = 0

# %%
# Adding ISurvey1 into studentResponses
im1s = pd.merge(students, im1, how='inner', on=['Email Address', 'Name'])

mod1Methods = methods[methods["Module #"] == 1]
for method in mod1Methods.Method:
    for SID in im1s["SID"]:
        row = (indAggResponses["SID"] == SID) & (indAggResponses["Method"] == method)
        indAggResponses.loc[row, "Selected"] = (im1s.loc[im1s["SID"] == SID, method + ".1"] == "Yes").values[0]
        indAggResponses.loc[row, "Familiar"] = (im1s.loc[im1s["SID"] == SID, method] == "Yes").values[0]
        indAggResponses.loc[row, "Reason"] = (im1s.loc[im1s["SID"] == SID, method + ".2"]).values[0]

# %%
# Adding All ISurveys into indAggResponses

im2 = pd.read_csv('IM2.csv', encoding='latin1')[1:27]
im3 = pd.read_csv('IM3.csv', encoding='latin1')[1:27]
im4 = pd.read_csv('IM4.csv', encoding='latin1')[1:27]
im5 = pd.read_csv('IM5.csv', encoding='latin1')[1:27]
iSurveys = [im2, im3, im4, im5]

for survey in iSurveys:
    survey.rename(columns={"Unnamed: 1": "Email Address"}, inplace=True)
    survey["Email Address"] = survey["Email Address"].apply(lambda str: str.lower())
    
#im2["Email Address"] = im2["Email Address"].apply(lambda str: str.lower())
#im3["Email Address"] = im3["Email Address"].apply(lambda str: str.lower())
#im4["Email Address"] = im4["Email Address"].apply(lambda str: str.lower())
#im5["Email Address"] = im5["Email Address"].apply(lambda str: str.lower())
iSurveysS = [pd.merge(students, survey, how='inner', on=['Email Address']) for survey in iSurveys]


im1s = pd.merge(students, im1, how='inner', on=['Email Address', 'Name'])
im1s.head()
for i in range(0, 4):
    survey = iSurveysS[i]
    mod1Methods = methods[methods["Module #"] == i + 2]
    for method in mod1Methods.Method:
        for SID in survey["SID"]:
            row = (indAggResponses["SID"] == SID) & (indAggResponses["Method"] == method)
            indAggResponses.loc[row, "Selected"] = (survey.loc[survey["SID"] == SID, method + ".1"] == "Yes").values[0]
            indAggResponses.loc[row, "Familiar"] = (survey.loc[survey["SID"] == SID, method] == "Yes").values[0]
            indAggResponses.loc[row, "Reason"] = (survey.loc[survey["SID"] == SID, method + ".2"]).values[0]

# %%
indAggResponses
# Out:
#                       Name             Email Address   SID  key Unnamed: 0  \
# 0     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_0
# 1     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_1
# 2     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_2
# 3     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_3
# 4     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_4
# 5     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_5
# 6     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_6
# 7     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_7
# 8     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_8
# 9     Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1        M_9
# 10    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_10
# 11    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_11
# 12    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_12
# 13    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_13
# 14    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_14
# 15    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_15
# 16    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_16
# 17    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_17
# 18    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_18
# 19    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_19
# 20    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_20
# 21    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_21
# 22    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_22
# 23    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_23
# 24    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_24
# 25    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_25
# 26    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_26
# 27    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_27
# 28    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_28
# 29    Bezerra, Tiago Tadeu  tiago.tadeu@berkeley.edu   S_0    1       M_29
# ...                    ...                       ...   ...  ...        ...
# 1660         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_35
# 1661         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_36
# 1662         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_37
# 1663         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_38
# 1664         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_39
# 1665         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_40
# 1666         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_41
# 1667         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_42
# 1668         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_43
# 1669         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_44
# 1670         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_45
# 1671         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_46
# 1672         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_47
# 1673         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_48
# 1674         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_49
# 1675         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_50
# 1676         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_51
# 1677         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_52
# 1678         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_53
# 1679         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_54
# 1680         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_55
# 1681         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_56
# 1682         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_57
# 1683         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_58
# 1684         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_59
# 1685         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_60
# 1686         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_61
# 1687         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_62
# 1688         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_63
# 1689         Yen, Yen Tina          v23515@gmail.com  S_25    1       M_64
#
#      Unnamed: 0.1  Module #       Module                           Method  \
# 0             M_0         1     Research                    1:1 Interview
# 1             M_1         1     Research                            AEIOU
# 2             M_2         1     Research              Closed Card Sorting
# 3             M_3         1     Research              Community Appraisal
# 4             M_4         1     Research             Competitive Analysis
# 5             M_5         1     Research                Conjoint Analysis
# 6             M_6         1     Research                Conversation Cafe
# 7             M_7         1     Research               Design Ethnography
# 8             M_8         1     Research                      Focus Group
# 9             M_9         1     Research                Open Card Sorting
# 10           M_10         1     Research                            POEMS
# 11           M_11         1     Research                            POSTA
# 12           M_12         1     Research                Usability Testing
# 13           M_13         1     Research                 User Observation
# 14           M_14         2     Analysis                       2x2 Matrix
# 15           M_15         2     Analysis                 Affinity Diagram
# 16           M_16         2     Analysis                          Atomize
# 17           M_17         2     Analysis                  Concept Mapping
# 18           M_18         2     Analysis                  Context Mapping
# 19           M_19         2     Analysis         Customer Journey Mapping
# 20           M_20         2     Analysis                      Empathy Map
# 21           M_21         2     Analysis                     How Might We
# 22           M_22         2     Analysis                    Kano Analysis
# 23           M_23         2     Analysis                     Mind Mapping
# 24           M_24         2     Analysis                     Powers of 10
# 25           M_25         2     Analysis                        Reframing
# 26           M_26         2     Analysis                 Spectrum Mapping
# 27           M_27         2     Analysis                    Task Analysis
# 28           M_28         2     Analysis                Touchpoint Matrix
# 29           M_29         2     Analysis                Why-How Laddering
# ...           ...       ...          ...                              ...
# 1660         M_35         3       Ideate                       Biomimicry
# 1661         M_36         3       Ideate               Borda Count Voting
# 1662         M_37         3       Ideate                    Brainstorming
# 1663         M_38         3       Ideate                Design Heuristics
# 1664         M_39         3       Ideate                   Design the Box
# 1665         M_40         3       Ideate                     Do-Redo-Undo
# 1666         M_41         3       Ideate                   Forced Analogy
# 1667         M_42         3       Ideate             Visual Brainstorming
# 1668         M_43         3       Ideate                  Weighted Matrix
# 1669         M_44         4        Build           Additive Manufacturing
# 1670         M_45         4        Build  Direct Shell Production Casting
# 1671         M_46         4        Build           Experience Prototyping
# 1672         M_47         4        Build       Fused Deposition Modelling
# 1673         M_48         4        Build   Laminated Object Manufacturing
# 1674         M_49         4        Build                    Laser Cutting
# 1675         M_50         4        Build                      Prototyping
# 1676         M_51         4        Build                Rapid Prototyping
# 1677         M_52         4        Build              Service Prototyping
# 1678         M_53         4        Build             Tangible Prototyping
# 1679         M_54         4        Build                Water Jet Cutting
# 1680         M_55         4        Build                        Wireframe
# 1681         M_56         5  Communicate                    7Ps Framework
# 1682         M_57         5  Communicate            Business Model Canvas
# 1683         M_58         5  Communicate             Composite Characters
# 1684         M_59         5  Communicate                   Design Roadmap
# 1685         M_60         5  Communicate               Envisionment Video
# 1686         M_61         5  Communicate                         Personas
# 1687         M_62         5  Communicate                Service Blueprint
# 1688         M_63         5  Communicate                       Storyboard
# 1689         M_64         5  Communicate                 Usability Report
#
#        MID Selected                                             Reason  \
# 0      M_0     True  I've never used this method, despite know abou...
# 1      M_1    False  Because in my routine as Product Manager and B...
# 2      M_2    False  Because in my routine as Product Manager and B...
# 3      M_3    False  As a Product Manager and Business Manager, I b...
# 4      M_4    False  As a Product Manager and Business Manager, I b...
# 5      M_5    False  As a Product Manager and Business Manager, I b...
# 6      M_6    False  As a Product Manager and Business Manager, I b...
# 7      M_7    False  Because in my routine as Product Manager and B...
# 8      M_8     True  Our business lives a moment to understand more...
# 9      M_9    False  Because in my routine as Product Manager and B...
# 10    M_10    False  Because in my routine as Product Manager and B...
# 11    M_11    False  Because in my routine as Product Manager and B...
# 12    M_12    False  As a Product Manager and Business Manager, I b...
# 13    M_13    False  As a Product Manager and Business Manager, I b...
# 14    M_14    False  I did not know the method. Interesting the app...
# 15    M_15    False  Interesting method, did not know it. However, ...
# 16    M_16    False  Interesting method, did not know it. However, ...
# 17    M_17    False  Interesting method, did not know it. However, ...
# 18    M_18    False  Interessante o mÍ©todo, nÍ£o o conhecia. No en...
# 19    M_19     True  Fantastic methodology. 100% customer-oriented ...
# 20    M_20     True  I have already applied this method in the comp...
# 21    M_21    False  I did not know the methodology. I did not choo...
# 22    M_22    False  Interesting method, did not know it. However, ...
# 23    M_23    False  Interesting method, especially to "get the hea...
# 24    M_24    False  I did not know the method. And, frankly, I cou...
# 25    M_25    False  I did not know the method. Interesting to appr...
# 26    M_26    False  I did not know the method. I did not choose it...
# 27    M_27    False  Interesting method, did not know it. However, ...
# 28    M_28    False  Interesting method, did not know it. However, ...
# 29    M_29     True  This method allows a background in the real re...
# ...    ...      ...                                                ...
# 1660  M_35    False  The process may be inefficient and the solutio...
# 1661  M_36    False  It takes time for each idea to be discussed be...
# 1662  M_37    False  Team members may feel stressful and unwilling ...
# 1663  M_38    False  I may feel  overwhelmed by the large number of...
# 1664  M_39    False  It may let team members to focus on salesmansh...
# 1665  M_40     True  We only need sticky notes to do this method an...
# 1666  M_41    False  It takes time to prepare and conduct a forced ...
# 1667  M_42     True  It can solve situations where many ideas have ...
# 1668  M_43    False  It is useful when there are several alternativ...
# 1669  M_44    False  AM is limited in size and is very expensive. I...
# 1670  M_45    False  DSPC is not available commercially yet and it ...
# 1671  M_46    False  This method needs to make multiple prototypes ...
# 1672  M_47    False  It is similar to laminated object and is slowe...
# 1673  M_48     True  LOM is inexpensive and simple. Since our produ...
# 1674  M_49    False  Laser Cutting will consume a lot of energy and...
# 1675  M_50     True  I can make my idea tangible and real. And it c...
# 1676  M_51    False  It needs some skill to use  laser cutter, wate...
# 1677  M_52    False  Participants are role-playing so they may not ...
# 1678  M_53     True  Materials for this method such as cardboard an...
# 1679  M_54    False  I may ruin my design if the material I use is ...
# 1680  M_55    False  This method is limited to more interaction and...
# 1681  M_56    False  It looks a little similar to Business model ca...
# 1682  M_57     True  It is quick to make and easy to understand, sh...
# 1683  M_58    False  Combining characters into one user can be a di...
# 1684  M_59    False  We may  receive ineffective feedback from othe...
# 1685  M_60    False  It takes time to make a video. Besides, we hav...
# 1686  M_61     True  It can separate  our team from the users, allo...
# 1687  M_62    False  May be hard to interpret with a lack of visual...
# 1688  M_63     True  It is an interactive activity that every team ...
# 1689  M_64    False  It can be ineffective if all points are not be...
#
#      Familiar
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
# 5       False
# 6        True
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19       True
# 20       True
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# ...       ...
# 1660    False
# 1661    False
# 1662    False
# 1663    False
# 1664    False
# 1665    False
# 1666    False
# 1667    False
# 1668    False
# 1669    False
# 1670    False
# 1671    False
# 1672    False
# 1673    False
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
#
# [1690 rows x 13 columns]

# %%
indAggResponses[(indAggResponses["Reason"] == "")].groupby(["Module #", "Name"]).size()
# Out:
# Module #  Name
# 4         Giron, Trisha Mae       12
#           Lu, Sifan               12
# 5         Chen, Shih Chi (Tim)     9
#           Lu, Sifan                9
# dtype: int64

# %%
# Team Roster
teamRoster = pd.read_csv('Team Roster.csv', encoding='latin1')[1:28]
teamRoster = pd.merge(teamRoster, students, on = ["Email Address"])
#teams = teams.groupby("Team")
teams = pd.DataFrame(columns = ["Team", "SID"])
for row in teamRoster[["Team", "SID", "Name"]].groupby("Team"):
    print(type(row[1]))
    print(row[1].SID.values)
    teams.loc[teams.shape[0]] = [row[0], row[1].SID.values]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['S_8' 'S_13' 'S_20' 'S_25']
# <class 'pandas.core.frame.DataFrame'>
# ['S_2' 'S_7' 'S_10' 'S_15']
# <class 'pandas.core.frame.DataFrame'>
# ['S_9' 'S_11' 'S_17' 'S_18' 'S_23']
# <class 'pandas.core.frame.DataFrame'>
# ['S_1' 'S_12' 'S_14' 'S_16']
# <class 'pandas.core.frame.DataFrame'>
# ['S_4' 'S_3' 'S_6' 'S_21']
# <class 'pandas.core.frame.DataFrame'>
# ['S_5' 'S_19' 'S_22' 'S_24']

# %%
teams
# Out:
#      Team                            SID
# 0  Team 1        [S_8, S_13, S_20, S_25]
# 1  Team 2         [S_2, S_7, S_10, S_15]
# 2  Team 3  [S_9, S_11, S_17, S_18, S_23]
# 3  Team 4        [S_1, S_12, S_14, S_16]
# 4  Team 5          [S_4, S_3, S_6, S_21]
# 5  Team 6        [S_5, S_19, S_22, S_24]

# %%
# Team Aggregate Responses
# Team, Module, Chosen Method (3 rows per team), Reason, Decision Process

teamAggResponses = pd.DataFrame(columns = ["Team", "Module", "Chosen Method", "Reason", "Decision Process"])

# %%
teamAggResponses = pd.DataFrame(columns = ["Team", "Module", "Chosen Method", "Reason", "Decision Process"])

# Note: deleted extra responses from team 1
tm1 = pd.read_csv('TM1.csv', encoding='latin1')
tm1

teamData = [pd.read_csv('TM%d.csv' % i, encoding='latin1') for i in range(1,5 + 1)]

for i in range(1, 5+1):
    team = teamData[i-1]
    for r in range(tm1.shape[0]):
        for q in range(0, 3):
            ri = teamAggResponses.shape[0] # + 1, + 2
            teamAggResponses.loc[ri, "Module"] = i
            teamAggResponses.loc[ri, "Team"] = team[team.columns[1]][r]
            teamAggResponses.loc[ri, "Chosen Method"] = team[team.columns[q*3 + 2]][r]
            teamAggResponses.loc[ri, "Reason"] = team[team.columns[q*3 + 4]][r]
            teamAggResponses.loc[ri, "Decision Process"] = team[team.columns[q*3 + 3]][r]

# %%
teamAggResponses.groupby(["Chosen Method", "Module"]).describe()
# Out:
#                                 Decision Process         \
#                                            count unique
# Chosen Method            Module
# 1:1 Interview            1                     6      6
# 2x2 Matrix               2                     3      3
# 3-12-3 Brainstorming     3                     1      1
# 6-3-5 Brainwriting       3                     1      1
# 6-Up Sketches            3                     1      1
# 7 Ps Framework           5                     2      2
# AEIOU                    1                     5      5
# Affinity Diagramming     2                     1      1
# Atomize                  2                     1      1
# Attribute Listing        3                     1      1
# Borda Count Voting       3                     1      1
# Brainstorming            3                     5      4
# Community Appraisal      1                     1      1
# Competitive Analysis     1                     2      2
# Composite Characters     5                     2      2
# Concept Map              2                     2      2
# Customer Journey Mapping 2                     2      2
# Design Heuristics        3                     3      1
# Design Roadmap           5                     5      5
# Empathy Map              2                     3      3
# Envisionment Videos      5                     1      1
# Experience Prototype     4                     2      2
# Fused Deposition Models  4                     1      1
# Kano Analysis            2                     1      1
# Mind Map                 2                     1      1
# Open Card Sorting        1                     1      1
# Personas                 5                     2      2
# Prototyping              4                     4      4
# Rapid Prototyping        4                     2      2
# Reframing                2                     1      1
# Service Blueprint        5                     1      1
# Service Prototype        4                     2      2
# Storyboards              5                     4      4
# Tangible Prototype       4                     2      2
# Task Analysis            2                     1      1
# The Anti-Problem         3                     1      1
# Usability Report         5                     1      1
# Usability Testing        1                     1      1
# User Observation         1                     2      2
# Visual Brainstorming     3                     1      1
# Weighted Matrix          3                     3      2
# Why-how Laddering        2                     2      2
# Wireframe                4                     5      5
#
#                                                                                     \
#                                                                                top
# Chosen Method            Module
# 1:1 Interview            1       Since we all come from different background. E...
# 2x2 Matrix               2       We took a vote on which 3 methods to use and t...
# 3-12-3 Brainstorming     3       3-12-3 Brainstorming provides us so limited ti...
# 6-3-5 Brainwriting       3       Now that weâve got our best ideas out in the...
# 6-Up Sketches            3       After reviewing the different methods in lectu...
# 7 Ps Framework           5        The team agreed that this method would clearl...
# AEIOU                    1       We discussed this as a group over online chat,...
# Affinity Diagramming     2       The members in our group are all creative, and...
# Atomize                  2       Again, in trying to find design methods that c...
# Attribute Listing        3       In ideate process, we wants to get as more ide...
# Borda Count Voting       3       While we were in class working on the process ...
# Brainstorming            3       Our team opted to using brainstorming as one o...
# Community Appraisal      1       There is a strong argument to be made about wh...
# Competitive Analysis     1       Once we have determined the design space we fi...
# Composite Characters     5       Our group firstly consider the university of o...
# Concept Map              2       Our team decided on using the concept map meth...
# Customer Journey Mapping 2       Charlie proposed this method and we all at the...
# Design Heuristics        3       As a team, we first were experimenting with di...
# Design Roadmap           5       Our team decided to use Design road mapping as...
# Empathy Map              2       Empathy map is a efficient method to organize ...
# Envisionment Videos      5       A few of us chose this method in our individua...
# Experience Prototype     4       The development of the product is currently on...
# Fused Deposition Models  4       Our team chose this building method because we...
# Kano Analysis            2       One of our team member points out that we need...
# Mind Map                 2       Mind map is a quick way to generate and organi...
# Open Card Sorting        1       Initially, our team was choosing between close...
# Personas                 5       Our team made up a character to better improve...
# Prototyping              4       Since our design team is in the build stage an...
# Rapid Prototyping        4       Several group members suggested using this met...
# Reframing                2       After having finished the research, we tried t...
# Service Blueprint        5       Someone suggested this method and others agree...
# Service Prototype        4       Allowing users to go through the service allow...
# Storyboards              5       At very beginning, our team opted to using sto...
# Tangible Prototype       4       While building a full scale street lamp seems ...
# Task Analysis            2       After evaluating all the options and pictured ...
# The Anti-Problem         3       The anti-problem was a common ideation method ...
# Usability Report         5       Our team found this method interesting in how ...
# Usability Testing        1       The identified problem(s) involve two sets of ...
# User Observation         1       With user observation, we can collect raw insi...
# Visual Brainstorming     3       Visual Brainstorming helps us to get a better ...
# Weighted Matrix          3       Our team chose weighted matrix as one of us id...
# Why-how Laddering        2       One team member suggested this method and othe...
# Wireframe                4       Wireframe is the build method given that most ...
#
#                                      Reason         \
#                                 freq  count unique
# Chosen Method            Module
# 1:1 Interview            1         1      6      6
# 2x2 Matrix               2         1      3      3
# 3-12-3 Brainstorming     3         1      1      1
# 6-3-5 Brainwriting       3         1      1      1
# 6-Up Sketches            3         1      1      1
# 7 Ps Framework           5         1      2      2
# AEIOU                    1         1      5      5
# Affinity Diagramming     2         1      1      1
# Atomize                  2         1      1      1
# Attribute Listing        3         1      1      1
# Borda Count Voting       3         1      1      1
# Brainstorming            3         2      5      4
# Community Appraisal      1         1      1      1
# Competitive Analysis     1         1      2      2
# Composite Characters     5         1      2      2
# Concept Map              2         1      2      2
# Customer Journey Mapping 2         1      2      2
# Design Heuristics        3         3      3      1
# Design Roadmap           5         1      5      5
# Empathy Map              2         1      3      3
# Envisionment Videos      5         1      1      1
# Experience Prototype     4         1      2      2
# Fused Deposition Models  4         1      1      1
# Kano Analysis            2         1      1      1
# Mind Map                 2         1      1      1
# Open Card Sorting        1         1      1      1
# Personas                 5         1      2      2
# Prototyping              4         1      4      4
# Rapid Prototyping        4         1      2      2
# Reframing                2         1      1      1
# Service Blueprint        5         1      1      1
# Service Prototype        4         1      2      2
# Storyboards              5         1      4      4
# Tangible Prototype       4         1      2      2
# Task Analysis            2         1      1      1
# The Anti-Problem         3         1      1      1
# Usability Report         5         1      1      1
# Usability Testing        1         1      1      1
# User Observation         1         1      2      2
# Visual Brainstorming     3         1      1      1
# Weighted Matrix          3         2      3      1
# Why-how Laddering        2         1      2      2
# Wireframe                4         1      5      5
#
#                                                                                     \
#                                                                                top
# Chosen Method            Module
# 1:1 Interview            1       As previously mentioned in the last question, ...
# 2x2 Matrix               2       Our other two methods focused on better unders...
# 3-12-3 Brainstorming     3       The factors we considered is whether we could ...
# 6-3-5 Brainwriting       3       We considered the pros and cons of this method...
# 6-Up Sketches            3       Since our goal during the ideate stage was to ...
# 7 Ps Framework           5        Since we have been through our design process...
# AEIOU                    1       We considered similar methods (POSTA/POEMS) an...
# Affinity Diagramming     2       After out 1:1 interviews, our team had a lot o...
# Atomize                  2       Atomization seems like a natural extension of ...
# Attribute Listing        3       In an integrated system, every parts act in th...
# Borda Count Voting       3       As we needed to narrow down the many options w...
# Brainstorming            3        In terms of structure, our team decided to ta...
# Community Appraisal      1       Since we would like encourage a sense of commu...
# Competitive Analysis     1       Our target population, at the moment, consists...
# Composite Characters     5       We believe that composite characters would hel...
# Concept Map              2       Our main motivator for choosing concept mappin...
# Customer Journey Mapping 2       User experience data is clearly organized by d...
# Design Heuristics        3       The main factors that contributed to our decis...
# Design Roadmap           5          After the second peer review, we received s...
# Empathy Map              2       Since we are aiming to help alleviate some of ...
# Envisionment Videos      5       We have members in our group that have experie...
# Experience Prototype     4       The first factor our group considered is the f...
# Fused Deposition Models  4       Since our team is doing a medical project in a...
# Kano Analysis            2       It lets us prioritize and categorize all the d...
# Mind Map                 2       It's really hard to start from the first/early...
# Open Card Sorting        1       We decided to go with the open card sorting me...
# Personas                 5       We believe that personas are important in that...
# Prototyping              4       Prototyping allows us to make our ideas tangib...
# Rapid Prototyping        4       Given the length of the class, some of the mor...
# Reframing                2       Our research focused on a fairly specific issu...
# Service Blueprint        5       This method makes sense to use because our pro...
# Service Prototype        4       The factors that contributed to our decision w...
# Storyboards              5       As mentioned above, we valued the visual aspec...
# Tangible Prototype       4       Tangible prototype is great because the method...
# Task Analysis            2       We decided on this method primarily because of...
# The Anti-Problem         3       The anti-problem interesting method utilized a...
# Usability Report         5       As mentioned previously, this method directly ...
# Usability Testing        1       Our problems requires that two sets of user wi...
# User Observation         1       The first factor we considered when choosing o...
# Visual Brainstorming     3       Through this method, it helps us to figure out...
# Weighted Matrix          3       Overall, they reason why weighted matrix was c...
# Why-how Laddering        2       We think this method would be a great way to f...
# Wireframe                4       Our design solution requires  both  a smart st...
#
#                                       Team
#                                 freq count unique     top freq
# Chosen Method            Module
# 1:1 Interview            1         1     6      6  Team 3    1
# 2x2 Matrix               2         1     3      3  Team 2    1
# 3-12-3 Brainstorming     3         1     1      1  Team 2    1
# 6-3-5 Brainwriting       3         1     1      1  Team 1    1
# 6-Up Sketches            3         1     1      1  Team 1    1
# 7 Ps Framework           5         1     2      2  Team 2    1
# AEIOU                    1         1     5      5  Team 4    1
# Affinity Diagramming     2         1     1      1  Team 1    1
# Atomize                  2         1     1      1  Team 4    1
# Attribute Listing        3         1     1      1  Team 2    1
# Borda Count Voting       3         1     1      1  Team 4    1
# Brainstorming            3         2     5      3  Team 3    3
# Community Appraisal      1         1     1      1  Team 2    1
# Competitive Analysis     1         1     2      2  Team 3    1
# Composite Characters     5         1     2      2  Team 3    1
# Concept Map              2         1     2      2  Team 3    1
# Customer Journey Mapping 2         1     2      2  Team 3    1
# Design Heuristics        3         3     3      1  Team 3    3
# Design Roadmap           5         1     5      5  Team 3    1
# Empathy Map              2         1     3      3  Team 2    1
# Envisionment Videos      5         1     1      1  Team 5    1
# Experience Prototype     4         1     2      2  Team 2    1
# Fused Deposition Models  4         1     1      1  Team 2    1
# Kano Analysis            2         1     1      1  Team 5    1
# Mind Map                 2         1     1      1  Team 2    1
# Open Card Sorting        1         1     1      1  Team 1    1
# Personas                 5         1     2      2  Team 2    1
# Prototyping              4         1     4      3  Team 3    2
# Rapid Prototyping        4         1     2      2  Team 4    1
# Reframing                2         1     1      1  Team 4    1
# Service Blueprint        5         1     1      1  Team 5    1
# Service Prototype        4         1     2      1  Team 3    2
# Storyboards              5         1     4      4  Team 4    1
# Tangible Prototype       4         1     2      2  Team 4    1
# Task Analysis            2         1     1      1  Team 3    1
# The Anti-Problem         3         1     1      1  Team 4    1
# Usability Report         5         1     1      1  Team 4    1
# Usability Testing        1         1     1      1  Team 2    1
# User Observation         1         1     2      2  Team 6    1
# Visual Brainstorming     3         1     1      1  Team 2    1
# Weighted Matrix          3         3     3      1  Team 3    3
# Why-how Laddering        2         1     2      2  Team 6    1
# Wireframe                4         1     5      4  Team 3    2

# %%
grouped = teamAggResponses[["Team", "Chosen Method", "Module"]].groupby(["Module", "Chosen Method"]).describe()
grouped
# Out:
#                                  Team
#                                 count unique     top freq
# Module Chosen Method
# 1      1:1 Interview                6      6  Team 3    1
#        AEIOU                        5      5  Team 4    1
#        Community Appraisal          1      1  Team 2    1
#        Competitive Analysis         2      2  Team 3    1
#        Open Card Sorting            1      1  Team 1    1
#        Usability Testing            1      1  Team 2    1
#        User Observation             2      2  Team 6    1
# 2      2x2 Matrix                   3      3  Team 2    1
#        Affinity Diagramming         1      1  Team 1    1
#        Atomize                      1      1  Team 4    1
#        Concept Map                  2      2  Team 3    1
#        Customer Journey Mapping     2      2  Team 3    1
#        Empathy Map                  3      3  Team 2    1
#        Kano Analysis                1      1  Team 5    1
#        Mind Map                     1      1  Team 2    1
#        Reframing                    1      1  Team 4    1
#        Task Analysis                1      1  Team 3    1
#        Why-how Laddering            2      2  Team 6    1
# 3      3-12-3 Brainstorming         1      1  Team 2    1
#        6-3-5 Brainwriting           1      1  Team 1    1
#        6-Up Sketches                1      1  Team 1    1
#        Attribute Listing            1      1  Team 2    1
#        Borda Count Voting           1      1  Team 4    1
#        Brainstorming                5      3  Team 3    3
#        Design Heuristics            3      1  Team 3    3
#        The Anti-Problem             1      1  Team 4    1
#        Visual Brainstorming         1      1  Team 2    1
#        Weighted Matrix              3      1  Team 3    3
# 4      Experience Prototype         2      2  Team 2    1
#        Fused Deposition Models      1      1  Team 2    1
#        Prototyping                  4      3  Team 3    2
#        Rapid Prototyping            2      2  Team 4    1
#        Service Prototype            2      1  Team 3    2
#        Tangible Prototype           2      2  Team 4    1
#        Wireframe                    5      4  Team 3    2
# 5      7 Ps Framework               2      2  Team 2    1
#        Composite Characters         2      2  Team 3    1
#        Design Roadmap               5      5  Team 3    1
#        Envisionment Videos          1      1  Team 5    1
#        Personas                     2      2  Team 2    1
#        Service Blueprint            1      1  Team 5    1
#        Storyboards                  4      4  Team 4    1
#        Usability Report             1      1  Team 4    1

# %%
# Exporting tables to csv
students.to_csv("studentData.csv")
methods.to_csv("methodData.csv")
modules.to_csv("moduleData.csv")
teams.to_csv("teamData.csv")
indAggResponses.to_csv("indAggResponses.csv")
teamAggResponses.to_csv("teamAggResponses.csv")

# %%
modules
# Out:
#             Module  Module #
# MOD_0     Research         1
# MOD_1     Analysis         2
# MOD_2       Ideate         3
# MOD_3        Build         4
# MOD_4  Communicate         5
